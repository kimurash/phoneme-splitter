# %%
# %%HTML
# <style>
#     body {
#         --vscode-font-family: "Consolas", "Noto Sans CJK JP Regular";
#         line-height: 180%;
#     }
# </style>
# Out:
# <style>
#     body {
#         --vscode-font-family: "Consolas", "Noto Sans CJK JP Regular";
#         line-height: 180%;
#     }
# </style>

# %%
import librosa
import soundfile as sf

import wave
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 音声ファイルを読み込んで波形を表示してみる．

# %%
SAMPLE_WAV = '../wav/output/C0001-230718_1.wav'

y, sr = librosa.load(SAMPLE_WAV, sr=16000, mono=True)
plt.plot(y);

# %% [markdown]
# soundfileで量子化bit数を変更して結果を確認する．

# %%
sf.write("result.wav", y, sr, subtype="PCM_16")

# %%
wv = wave.open('./result.wav', 'rb')

print(wv.getnchannels())
print(wv.getsampwidth()) # 1サンプルのバイト数
print(wv.getframerate()) # サンプリング周波数
print(wv.getnframes())
# Out:
# 1
# 2
# 16000
# 92365
